# %%
import numpy as np
import pandas as pd
#import tensorflow as tf
#import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df = pd.read_csv(r"C:\Users\priya\Documents\New folder\ML\project\How-To-Not-Lose-A-Customer-In-10-Days.-main\98efc33085a711eb\dataset\train.csv")

# %%
df.head()
no_rows = df.shape[0]
no_columns = df.shape[1]

# %%
df = df.drop(['customer_id','Name','security_no','referral_id'],axis = 1)

# %%
df.head()
# Out:
#    age gender region_category  membership_category joining_date  \
# 0   18      F         Village  Platinum Membership   2017-08-17
# 1   32      F            City   Premium Membership   2017-08-28
# 2   44      F            Town        No Membership   2016-11-11
# 3   37      M            City        No Membership   2016-10-29
# 4   31      F            City        No Membership   2017-09-12
#
#   joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                      No     Gift Vouchers/Coupons                   ?
# 1                       ?     Gift Vouchers/Coupons             Desktop
# 2                     Yes     Gift Vouchers/Coupons             Desktop
# 3                     Yes     Gift Vouchers/Coupons             Desktop
# 4                      No  Credit/Debit Card Offers          Smartphone
#
#   internet_option last_visit_time  ...  avg_time_spent  avg_transaction_value  \
# 0           Wi-Fi        16:08:02  ...          300.63               53005.25
# 1     Mobile_Data        12:38:13  ...          306.34               12838.38
# 2           Wi-Fi        22:53:21  ...          516.16               21027.00
# 3     Mobile_Data        15:57:50  ...           53.27               25239.56
# 4     Mobile_Data        15:46:44  ...          113.13               24483.66
#
#    avg_frequency_login_days points_in_wallet  used_special_discount  \
# 0                      17.0           781.75                    Yes
# 1                      10.0              NaN                    Yes
# 2                      22.0           500.69                     No
# 3                       6.0           567.66                     No
# 4                      16.0           663.06                     No
#
#   offer_application_preference past_complaint     complaint_status  \
# 0                          Yes             No       Not Applicable
# 1                           No            Yes               Solved
# 2                          Yes            Yes  Solved in Follow-up
# 3                          Yes            Yes             Unsolved
# 4                          Yes            Yes               Solved
#
#                    feedback churn_risk_score
# 0  Products always in Stock                2
# 1     Quality Customer Care                1
# 2              Poor Website                5
# 3              Poor Website                5
# 4              Poor Website                5
#
# [5 rows x 21 columns]

# %%
df['last_visit_time']
# Out:
# 0        16:08:02
# 1        12:38:13
# 2        22:53:21
# 3        15:57:50
# 4        15:46:44
#            ...
# 36987    04:14:05
# 36988    23:18:31
# 36989    03:50:25
# 36990    09:50:03
# 36991    01:39:52
# Name: last_visit_time, Length: 36992, dtype: object

# %%
 #This step converts all the missing and irrelevant data  present in the dataframe to NaN
def convert_to_NaN(df):
    for column in df:
        df[column] = df[column].apply(lambda x: np.nan if x == '?' or x == 'Error' or x == 'No Information Available' or x == 'No reason specified' else x)        
    df.fillna(0,inplace = True)
    return df

# %%
df = convert_to_NaN(df)
#convert negatives to zero
num = df._get_numeric_data()
num[num<0] = 0

# %%
df
# Out:
#        age gender region_category  membership_category joining_date  \
# 0       18      F         Village  Platinum Membership   2017-08-17
# 1       32      F            City   Premium Membership   2017-08-28
# 2       44      F            Town        No Membership   2016-11-11
# 3       37      M            City        No Membership   2016-10-29
# 4       31      F            City        No Membership   2017-09-12
# ...    ...    ...             ...                  ...          ...
# 36987   46      F               0     Basic Membership   2017-09-21
# 36988   29      F            Town     Basic Membership   2016-06-27
# 36989   23      F               0     Basic Membership   2016-09-11
# 36990   53      M         Village  Platinum Membership   2017-06-15
# 36991   35      M            Town    Silver Membership   2015-10-23
#
#       joined_through_referral     preferred_offer_types medium_of_operation  \
# 0                          No     Gift Vouchers/Coupons                   0
# 1                           0     Gift Vouchers/Coupons             Desktop
# 2                         Yes     Gift Vouchers/Coupons             Desktop
# 3                         Yes     Gift Vouchers/Coupons             Desktop
# 4                          No  Credit/Debit Card Offers          Smartphone
# ...                       ...                       ...                 ...
# 36987                      No  Credit/Debit Card Offers             Desktop
# 36988                      No            Without Offers          Smartphone
# 36989                     Yes     Gift Vouchers/Coupons             Desktop
# 36990                      No     Gift Vouchers/Coupons          Smartphone
# 36991                      No     Gift Vouchers/Coupons             Desktop
#
#       internet_option last_visit_time  ...  avg_time_spent  \
# 0               Wi-Fi        16:08:02  ...          300.63
# 1         Mobile_Data        12:38:13  ...          306.34
# 2               Wi-Fi        22:53:21  ...          516.16
# 3         Mobile_Data        15:57:50  ...           53.27
# 4         Mobile_Data        15:46:44  ...          113.13
# ...               ...             ...  ...             ...
# 36987           Wi-Fi        04:14:05  ...            0.00
# 36988           Wi-Fi        23:18:31  ...            0.00
# 36989           Wi-Fi        03:50:25  ...          154.94
# 36990     Mobile_Data        09:50:03  ...          482.61
# 36991     Mobile_Data        01:39:52  ...           79.18
#
#        avg_transaction_value  avg_frequency_login_days points_in_wallet  \
# 0                   53005.25                      17.0       781.750000
# 1                   12838.38                      10.0         0.000000
# 2                   21027.00                      22.0       500.690000
# 3                   25239.56                       6.0       567.660000
# 4                   24483.66                      16.0       663.060000
# ...                      ...                       ...              ...
# 36987               27277.68                       6.0       639.510000
# 36988               11069.71                      28.0       527.990000
# 36989               38127.56                         0       680.470000
# 36990                2378.86                      20.0       197.264414
# 36991                2189.68                         0       719.970000
#
#        used_special_discount offer_application_preference past_complaint  \
# 0                        Yes                          Yes             No
# 1                        Yes                           No            Yes
# 2                         No                          Yes            Yes
# 3                         No                          Yes            Yes
# 4                         No                          Yes            Yes
# ...                      ...                          ...            ...
# 36987                     No                          Yes            Yes
# 36988                    Yes                           No             No
# 36989                     No                          Yes            Yes
# 36990                    Yes                          Yes             No
# 36991                    Yes                           No             No
#
#           complaint_status                  feedback churn_risk_score
# 0           Not Applicable  Products always in Stock                2
# 1                   Solved     Quality Customer Care                1
# 2      Solved in Follow-up              Poor Website                5
# 3                 Unsolved              Poor Website                5
# 4                   Solved              Poor Website                5
# ...                    ...                       ...              ...
# 36987                    0                         0                4
# 36988       Not Applicable     Poor Customer Service                5
# 36989             Unsolved              Poor Website                4
# 36990       Not Applicable                         0                3
# 36991       Not Applicable     Quality Customer Care                2
#
# [36992 rows x 21 columns]

# %%
def convert_time(df):
    df['last_visit_time'] = pd.to_datetime(df['last_visit_time'],format = '%H:%M:%S')
    reference_time = ['23:59:59']*no_rows
    df['reference_time'] = reference_time
    df['reference_time'] = pd.to_datetime(df['reference_time'],format = '%H:%M:%S')
    df['seconds_since_last_visit'] = ( df['reference_time'] - df['last_visit_time'] ).dt.total_seconds()
    #df['seconds_since_last_visit']
    df = df.drop(['last_visit_time','reference_time'],axis = 1)
    return df

# %%
def convert_date(df):
    df['joining_date'] = pd.to_datetime(df['joining_date'], format = "%Y-%m-%d")
    const = ['2021-12-31']*no_rows
    df['const'] = const
    df['const'] = pd.to_datetime(df['const'], format = "%Y-%m-%d")
    #df['const']
    df['days_since_joining'] = df['const'] - df['joining_date']    
    df['days_since_joining'] = df['days_since_joining'] / np.timedelta64(1,'D')
    df = df.drop(['joining_date','const'],axis = 1)
    #df
    return df

# %%
def Encoder(df):
          columnsToEncode = list(df.select_dtypes(include=['category','object']))
          le = LabelEncoder()
          for feature in columnsToEncode:
              df[feature] = le.fit_transform(df[feature].astype(str))  
              try:
                  df[feature] = le.fit_transform(df[feature])
              except:
                  print('Error encoding '+feature)
          return df

# %%
df = convert_time(df)
df = convert_date(df)
df = Encoder(df)
df
# Out:
#        age  gender  region_category  membership_category  \
# 0       18       0                3                    3
# 1       32       0                1                    4
# 2       44       0                2                    2
# 3       37       1                1                    2
# 4       31       0                1                    2
# ...    ...     ...              ...                  ...
# 36987   46       0                0                    0
# 36988   29       0                2                    0
# 36989   23       0                0                    0
# 36990   53       1                3                    3
# 36991   35       1                2                    5
#
#        joined_through_referral  preferred_offer_types  medium_of_operation  \
# 0                            1                      2                    0
# 1                            0                      2                    2
# 2                            2                      2                    2
# 3                            2                      2                    2
# 4                            1                      1                    3
# ...                        ...                    ...                  ...
# 36987                        1                      1                    2
# 36988                        1                      3                    3
# 36989                        2                      2                    2
# 36990                        1                      2                    3
# 36991                        1                      2                    2
#
#        internet_option  days_since_last_login  avg_time_spent  ...  \
# 0                    2                     17          300.63  ...
# 1                    1                     16          306.34  ...
# 2                    2                     14          516.16  ...
# 3                    1                     11           53.27  ...
# 4                    1                     20          113.13  ...
# ...                ...                    ...             ...  ...
# 36987                2                      2            0.00  ...
# 36988                2                     13            0.00  ...
# 36989                2                     12          154.94  ...
# 36990                1                     15          482.61  ...
# 36991                1                     15           79.18  ...
#
#        avg_frequency_login_days  points_in_wallet  used_special_discount  \
# 0                           747        781.750000                      1
# 1                           733          0.000000                      1
# 2                           780        500.690000                      0
# 3                          1638        567.660000                      0
# 4                           744        663.060000                      0
# ...                         ...               ...                    ...
# 36987                      1638        639.510000                      0
# 36988                       810        527.990000                      1
# 36989                       683        680.470000                      0
# 36990                       775        197.264414                      1
# 36991                       683        719.970000                      1
#
#        offer_application_preference  past_complaint  complaint_status  \
# 0                                 1               0                 1
# 1                                 0               1                 2
# 2                                 1               1                 3
# 3                                 1               1                 4
# 4                                 1               1                 2
# ...                             ...             ...               ...
# 36987                             1               1                 0
# 36988                             0               0                 1
# 36989                             1               1                 4
# 36990                             1               0                 1
# 36991                             0               0                 1
#
#        feedback  churn_risk_score  seconds_since_last_visit  \
# 0             4                 2                   28317.0
# 1             5                 1                   40906.0
# 2             3                 5                    3998.0
# 3             3                 5                   28929.0
# 4             3                 5                   29595.0
# ...         ...               ...                       ...
# 36987         0                 4                   71154.0
# 36988         1                 5                    2488.0
# 36989         3                 4                   72574.0
# 36990         0                 3                   50996.0
# 36991         5                 2                   80407.0
#
#        days_since_joining
# 0                  1597.0
# 1                  1586.0
# 2                  1876.0
# 3                  1889.0
# 4                  1571.0
# ...                   ...
# 36987              1562.0
# 36988              2013.0
# 36989              1937.0
# 36990              1660.0
# 36991              2261.0
#
# [36992 rows x 21 columns]

# %%
#feature scaling 
from sklearn.preprocessing import MinMaxScaler
Scaler = MinMaxScaler()
df[['avg_time_spent','avg_transaction_value','avg_frequency_login_days','days_since_last_login','points_in_wallet','seconds_since_last_visit','days_since_joining']] = Scaler.fit_transform(df[['avg_time_spent','avg_transaction_value','avg_frequency_login_days','days_since_last_login','points_in_wallet','seconds_since_last_visit','days_since_joining']])
df
# Out:
#        age  gender  region_category  membership_category  \
# 0       18       0                3                    3
# 1       32       0                1                    4
# 2       44       0                2                    2
# 3       37       1                1                    2
# 4       31       0                1                    2
# ...    ...     ...              ...                  ...
# 36987   46       0                0                    0
# 36988   29       0                2                    0
# 36989   23       0                0                    0
# 36990   53       1                3                    3
# 36991   35       1                2                    5
#
#        joined_through_referral  preferred_offer_types  medium_of_operation  \
# 0                            1                      2                    0
# 1                            0                      2                    2
# 2                            2                      2                    2
# 3                            2                      2                    2
# 4                            1                      1                    3
# ...                        ...                    ...                  ...
# 36987                        1                      1                    2
# 36988                        1                      3                    3
# 36989                        2                      2                    2
# 36990                        1                      2                    3
# 36991                        1                      2                    2
#
#        internet_option  days_since_last_login  avg_time_spent  ...  \
# 0                    2               0.653846        0.092914  ...
# 1                    1               0.615385        0.094679  ...
# 2                    2               0.538462        0.159526  ...
# 3                    1               0.423077        0.016464  ...
# 4                    1               0.769231        0.034964  ...
# ...                ...                    ...             ...  ...
# 36987                2               0.076923        0.000000  ...
# 36988                2               0.500000        0.000000  ...
# 36989                2               0.461538        0.047886  ...
# 36990                1               0.576923        0.149157  ...
# 36991                1               0.576923        0.024472  ...
#
#        avg_frequency_login_days  points_in_wallet  used_special_discount  \
# 0                      0.451906          0.377827                      1
# 1                      0.443436          0.000000                      1
# 2                      0.471869          0.241988                      0
# 3                      0.990926          0.274355                      0
# 4                      0.450091          0.320463                      0
# ...                         ...               ...                    ...
# 36987                  0.990926          0.309081                      0
# 36988                  0.490018          0.255182                      1
# 36989                  0.413188          0.328877                      0
# 36990                  0.468845          0.095340                      1
# 36991                  0.413188          0.347968                      1
#
#        offer_application_preference  past_complaint  complaint_status  \
# 0                                 1               0                 1
# 1                                 0               1                 2
# 2                                 1               1                 3
# 3                                 1               1                 4
# 4                                 1               1                 2
# ...                             ...             ...               ...
# 36987                             1               1                 0
# 36988                             0               0                 1
# 36989                             1               1                 4
# 36990                             1               0                 1
# 36991                             0               0                 1
#
#        feedback  churn_risk_score  seconds_since_last_visit  \
# 0             4                 2                  0.327747
# 1             5                 1                  0.473455
# 2             3                 5                  0.046274
# 3             3                 5                  0.334830
# 4             3                 5                  0.342539
# ...         ...               ...                       ...
# 36987         0                 4                  0.823551
# 36988         1                 5                  0.028797
# 36989         3                 4                  0.839987
# 36990         0                 3                  0.590238
# 36991         5                 2                  0.930647
#
#        days_since_joining
# 0                0.124201
# 1                0.114155
# 2                0.378995
# 3                0.390868
# 4                0.100457
# ...                   ...
# 36987            0.092237
# 36988            0.504110
# 36989            0.434703
# 36990            0.181735
# 36991            0.730594
#
# [36992 rows x 21 columns]

# %%
#Y is the dependent variable or output
Y = df.iloc[:,-3].values
Y
df = df.drop(['churn_risk_score'],axis = 1)
df
# Out:
#        age  gender  region_category  membership_category  \
# 0       18       0                3                    3
# 1       32       0                1                    4
# 2       44       0                2                    2
# 3       37       1                1                    2
# 4       31       0                1                    2
# ...    ...     ...              ...                  ...
# 36987   46       0                0                    0
# 36988   29       0                2                    0
# 36989   23       0                0                    0
# 36990   53       1                3                    3
# 36991   35       1                2                    5
#
#        joined_through_referral  preferred_offer_types  medium_of_operation  \
# 0                            1                      2                    0
# 1                            0                      2                    2
# 2                            2                      2                    2
# 3                            2                      2                    2
# 4                            1                      1                    3
# ...                        ...                    ...                  ...
# 36987                        1                      1                    2
# 36988                        1                      3                    3
# 36989                        2                      2                    2
# 36990                        1                      2                    3
# 36991                        1                      2                    2
#
#        internet_option  days_since_last_login  avg_time_spent  \
# 0                    2               0.653846        0.092914
# 1                    1               0.615385        0.094679
# 2                    2               0.538462        0.159526
# 3                    1               0.423077        0.016464
# 4                    1               0.769231        0.034964
# ...                ...                    ...             ...
# 36987                2               0.076923        0.000000
# 36988                2               0.500000        0.000000
# 36989                2               0.461538        0.047886
# 36990                1               0.576923        0.149157
# 36991                1               0.576923        0.024472
#
#        avg_transaction_value  avg_frequency_login_days  points_in_wallet  \
# 0                   0.526717                  0.451906          0.377827
# 1                   0.121456                  0.443436          0.000000
# 2                   0.204074                  0.471869          0.241988
# 3                   0.246577                  0.990926          0.274355
# 4                   0.238950                  0.450091          0.320463
# ...                      ...                       ...               ...
# 36987               0.267140                  0.990926          0.309081
# 36988               0.103611                  0.490018          0.255182
# 36989               0.376609                  0.413188          0.328877
# 36990               0.015925                  0.468845          0.095340
# 36991               0.014016                  0.413188          0.347968
#
#        used_special_discount  offer_application_preference  past_complaint  \
# 0                          1                             1               0
# 1                          1                             0               1
# 2                          0                             1               1
# 3                          0                             1               1
# 4                          0                             1               1
# ...                      ...                           ...             ...
# 36987                      0                             1               1
# 36988                      1                             0               0
# 36989                      0                             1               1
# 36990                      1                             1               0
# 36991                      1                             0               0
#
#        complaint_status  feedback  seconds_since_last_visit  \
# 0                     1         4                  0.327747
# 1                     2         5                  0.473455
# 2                     3         3                  0.046274
# 3                     4         3                  0.334830
# 4                     2         3                  0.342539
# ...                 ...       ...                       ...
# 36987                 0         0                  0.823551
# 36988                 1         1                  0.028797
# 36989                 4         3                  0.839987
# 36990                 1         0                  0.590238
# 36991                 1         5                  0.930647
#
#        days_since_joining
# 0                0.124201
# 1                0.114155
# 2                0.378995
# 3                0.390868
# 4                0.100457
# ...                   ...
# 36987            0.092237
# 36988            0.504110
# 36989            0.434703
# 36990            0.181735
# 36991            0.730594
#
# [36992 rows x 20 columns]

# %%
#used here to transform categorical data
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('cat', OneHotEncoder(), ['gender','region_category','membership_category','joined_through_referral','preferred_offer_types','medium_of_operation','internet_option','used_special_discount','offer_application_preference','past_complaint','complaint_status','feedback'])], remainder='passthrough')
X = np.array(ct.fit_transform(df))

# %%
X
# Out:
# array([[1.        , 0.        , 0.        , ..., 0.3778268 , 0.32774685,
#         0.12420091],
#        [1.        , 0.        , 0.        , ..., 0.        , 0.47345455,
#         0.11415525],
#        [1.        , 0.        , 0.        , ..., 0.24198797, 0.04627368,
#         0.37899543],
#        ...,
#        [1.        , 0.        , 0.        , ..., 0.32887726, 0.83998657,
#         0.4347032 ],
#        [0.        , 1.        , 0.        , ..., 0.09533966, 0.59023831,
#         0.18173516],
#        [0.        , 1.        , 0.        , ..., 0.34796797, 0.93064735,
#         0.73059361]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, train_size = 0.8, random_state = 42)

# %%
'''from sklearn.ensemble import RandomForestClassifier 
model = RandomForestClassifier(n_estimators = 1000, criterion = 'entropy',n_jobs=-1, random_state = 22, verbose = 1)'''
# Out:
# "from sklearn.ensemble import RandomForestClassifier \nmodel = RandomForestClassifier(n_estimators = 1000, criterion = 'entropy',n_jobs=-1, random_state = 22, verbose = 1)"

# %%
'''from sklearn import model_selection'''
# Out:
# 'from sklearn import model_selection'

# %%
#scores = model_selection.cross_val_score(model, X_train, y_train, cv = 5)
#print(scores)

# %%
'''model.fit(X_train, y_train)'''
# Out:
# 'model.fit(X_train, y_train)'

# %%
'''print(model.score(X_test, y_test))'''
# Out:
# 'print(model.score(X_test, y_test))'

# %%
'''from sklearn.linear_model import LogisticRegression 
clf = LogisticRegression(random_state = 0, max_iter = 100)
clf.fit(X_train, y_train)
print(clf.score(X_test,y_test))'''
# Out:
# 'from sklearn.linear_model import LogisticRegression \nclf = LogisticRegression(random_state = 0, max_iter = 100)\nclf.fit(X_train, y_train)\nprint(clf.score(X_test,y_test))'

# %%
'''from sklearn.svm import SVC
svm = SVC(probability = True)
svm.fit(X_train, y_train)
print(svm.score(X_test, y_test))'''
# Out:
# 'from sklearn.svm import SVC\nsvm = SVC(probability = True)\nsvm.fit(X_train, y_train)\nprint(svm.score(X_test, y_test))'

# %%
from sklearn.ensemble import RandomForestClassifier 
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

clf = LogisticRegression(random_state = 0, max_iter = 1000)
model = RandomForestClassifier(n_estimators = 1000, criterion = 'entropy',n_jobs=-1, random_state = 22, verbose = 1)
svm = SVC(probability = True)

voting_clf = VotingClassifier(
    estimators = [('lr', clf), ('rf', model), ('svm', svm)],
    voting = 'soft')
voting_clf.fit(X_train, y_train)
print(voting_clf.score(X_test, y_test))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 238 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 738 tasks      | elapsed:   14.7s
# [Parallel(n_jobs=-1)]: Done 989 out of 1000 | elapsed:   19.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:   19.2s finished

# %%
from sklearn.ensemble import BaggingClassifier 
from sklearn.tree import DecisionTreeClassifier

bag_clf = BaggingClassifier(
    DecisionTreeClassifier(), n_estimators = 500,
    max_samples = 100, bootstrap = True, n_jobs = -1)
bag_clf.fit(X_train, y_train)
bag_clf.score(X_test, y_test)
# Out:
# 0.6771185295310177
